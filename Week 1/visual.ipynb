# %%
import pandas as pd

# %% [markdown]
# # Loading and viewing the data

# %%
data = pd.read_csv('anscombe dataset.csv')
data
# Out:
#     x1  x2  x3  x4     y1    y2     y3     y4
# 0   10  10  10   8   8.04  9.14   7.46   6.58
# 1    8   8   8   8   6.95  8.14   6.77   5.76
# 2   13  13  13   8   7.58  8.74  12.74   7.71
# 3    9   9   9   8   8.81  8.77   7.11   8.84
# 4   11  11  11   8   8.33  9.26   7.81   8.47
# 5   14  14  14   8   9.96  8.10   8.84   7.04
# 6    6   6   6   8   7.24  6.13   6.08   5.25
# 7    4   4   4  19   4.26  3.10   5.39  12.50
# 8   12  12  12   8  10.84  9.13   8.15   5.56
# 9    7   7   7   8   4.82  7.26   6.42   7.91
# 10   5   5   5   8   5.68  4.74   5.73   6.89

# %% [markdown]
# # Descrptive Statistics

# %%
data.describe(include='all')
# Out:
#               x1         x2         x3         x4         y1         y2  \
# count  11.000000  11.000000  11.000000  11.000000  11.000000  11.000000
# mean    9.000000   9.000000   9.000000   9.000000   7.500909   7.500909
# std     3.316625   3.316625   3.316625   3.316625   2.031568   2.031657
# min     4.000000   4.000000   4.000000   8.000000   4.260000   3.100000
# 25%     6.500000   6.500000   6.500000   8.000000   6.315000   6.695000
# 50%     9.000000   9.000000   9.000000   8.000000   7.580000   8.140000
# 75%    11.500000  11.500000  11.500000   8.000000   8.570000   8.950000
# max    14.000000  14.000000  14.000000  19.000000  10.840000   9.260000
#
#               y3         y4
# count  11.000000  11.000000
# mean    7.500000   7.500909
# std     2.030424   2.030579
# min     5.390000   5.250000
# 25%     6.250000   6.170000
# 50%     7.110000   7.040000
# 75%     7.980000   8.190000
# max    12.740000  12.500000

# %% [markdown]
# # Mean

# %% [markdown]
# - Mean of x1 is 9.000
# - Mean of x2 is 9.000
# - Mean of x3 is 9.000
# - Mean of x4 is 9.000
# - Mean of y1 is 7.501
# - Mean of y2 is 7.501
# - Mean of y3 is 7.500
# - Mean of y4 is 7.501

# %% [markdown]
# - The above mean shows the central tendancy of the data but interesting all four datasets have identical means for both X and Y variables

# %% [markdown]
# # Standard Variation

# %% [markdown]
# - This is used to show the average distance of values from the mean. Thus a similar variablility around the mean

# %% [markdown]
# - SD of x1 is 3.316625
# - SD of x2 is 3.316625
# - SD of x3 is 3.316625
# - SD of x4 is 3.316625
# - SD of y1 is 2.031568
# - SD of y2 is 2.031657
# - SD of y3 is 2.031657
# - SD of y4 is 2.031657

# %% [markdown]
# # Variance

# %%
import numpy as np

# %%
np.var(data)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/numpy/core/fromnumeric.py:3785: FutureWarning: The behavior of DataFrame.var with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return var(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)
# x1    10.000000
# x2    10.000000
# x3    10.000000
# x4    10.000000
# y1     3.752063
# y2     3.752390
# y3     3.747836
# y4     3.748408
# dtype: float64

# %% [markdown]
# - Variance is used to show how the data is spread and in this case we can tell that the four datasets have the same variance

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,6))
plt.scatter(data['x1'],data['y1'],color = 'blue')
m, c = np.polyfit(data['x1'], data['y1'], 1)   # slope and intercept
y_fit = m * data['x1'] + c

plt.plot(data['x1'], y_fit)
plt.title("Scatter plot of X1 against Y1")
plt.xlabel("x1")
plt.ylabel("y1")

plt.tight_layout()
plt.show()

# %% [markdown]
# - The scatter plot shows a positive relationship between X1 and Y1, where Y1 generally increases as X1 increases. The line of best fit shows a positive linear trend.

# %%
plt.figure(figsize=(8,6))
plt.scatter(data['x2'],data['y2'],color = 'blue')
m, c = np.polyfit(data['x2'], data['y2'], 1)   # slope and intercept
y_fit = m * data['x1'] + c

plt.plot(data['x2'], y_fit)
plt.title("Scatter plot of X2 against Y2")
plt.xlabel("x2")
plt.ylabel("y2")

plt.tight_layout()
plt.show()

# %% [markdown]
# - The scatter plot shows a positive linear relationship between x and y. As X increases, Y also generally increases and line of best fit slopes upward showing a positive correlation. There seems to be a point farthest from the line of best fit at x=4; other than that most of the points are just scattered around the line suggesting a moderately strong relationship between the variables

# %%
plt.figure(figsize=(8,6))
plt.scatter(data['x3'],data['y3'],color = 'blue')
m, c = np.polyfit(data['x3'], data['y3'], 1)   # slope and intercept
y_fit = m * data['x1'] + c

plt.plot(data['x3'], y_fit)
plt.title("Scatter plot of X3 against Y3")
plt.xlabel("x3")
plt.ylabel("y3")

plt.tight_layout()
plt.show()

# %% [markdown]
# - The scatter plot shows a positive linear relationship between x and y. As X increases, Y also generally increases and line of best fit slopes upward showing a positive correlation. There seems to be a point farthest from the line of best fit at x=4; other than that most of the points are just scattered around the line suggesting a moderately strong relationship between the variables

# %%
plt.figure(figsize=(8,6))
plt.scatter(data['x4'],data['y4'],color = 'blue')
m, c = np.polyfit(data['x4'], data['y4'], 1)   # slope and intercept
y_fit = m * data['x4'] + c

plt.plot(data['x4'], y_fit)
plt.title("Scatter plot of X4 against Y4")
plt.xlabel("x4")
plt.ylabel("y4")

plt.tight_layout()
plt.show()
