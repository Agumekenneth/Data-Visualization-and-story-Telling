# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('how-couples-met.csv')
df #display dataframe
# Out:
#    decade  college  at work  through friends  through family  online  \
# 0  1960.0     12.2     18.2             45.9            30.4     0.0
# 1  1970.0     16.4     23.9             48.9            28.6     0.0
# 2  1980.0     10.2     32.4             36.6            20.2     0.3
# 3  1990.0     10.5     30.7             35.9            18.5     3.2
# 4  2000.0     10.6     20.3             38.1            15.2    22.6
# 5  2010.0      6.7     15.5             28.9            10.0    42.2
#
#    restaurant  neighbors
# 0        21.5       11.6
# 1        25.0        8.9
# 2        28.3        8.0
# 3        26.2        7.7
# 4        18.5        8.8
# 5        14.0        4.3

# %%
df.isnull().sum() #check for missing values in the dataframe
# Out:
# decade             0
# college            0
# at work            0
# through friends    0
# through family     0
# online             0
# restaurant         0
# neighbors          0
# dtype: int64

# %%
df.plot()
# Out:
# <Axes: >

# %%
df= df.set_index('decade')
df
# Out:
#         college  at work  through friends  through family  online  restaurant  \
# decade
# 1960.0     12.2     18.2             45.9            30.4     0.0        21.5
# 1970.0     16.4     23.9             48.9            28.6     0.0        25.0
# 1980.0     10.2     32.4             36.6            20.2     0.3        28.3
# 1990.0     10.5     30.7             35.9            18.5     3.2        26.2
# 2000.0     10.6     20.3             38.1            15.2    22.6        18.5
# 2010.0      6.7     15.5             28.9            10.0    42.2        14.0
#
#         neighbors
# decade
# 1960.0       11.6
# 1970.0        8.9
# 1980.0        8.0
# 1990.0        7.7
# 2000.0        8.8
# 2010.0        4.3

# %%
df.plot()
# Out:
# <Axes: xlabel='decade'>
