# %%
import pandas as pd
import matplotlib.pyplot as plt
divers = pd.read_csv('longest-diving-animals.csv')
divers #display the dataframe
# Out:
#                          animal              category  duration
# 0               Emperor Penguin              penguins      32.2
# 1                  King Penguin              penguins       9.2
# 2            Rockhopper Penguin              penguins       3.2
# 3              Macaroni Penguin              penguins       6.3
# 4                 Royal Penguin              penguins       7.5
# ..                          ...                   ...       ...
# 103  North Atlantic Right Whale         baleen whales      16.3
# 104              Humpback Whale         baleen whales      24.0
# 105             Atlantic Walrus              walruses      49.0
# 106                     Dungong  other marine mammals      10.0
# 107             Florida Manatee  other marine mammals      24.0
#
# [108 rows x 3 columns]

# %%
divers.isnull().sum() #check for missing values in the dataframe
# Out:
# animal      0
# category    0
# duration    0
# dtype: int64

# %%
divers['category'].value_counts() #check the unique values in the category column
# Out:
# category
# other seabirds          40
# seals                   24
# penguins                14
# toothed whales          14
# baleen whales            7
# sea lions                5
# other marine mammals     2
# turtles                  1
# walruses                 1
# Name: count, dtype: int64

# %%
longest_duration = divers.groupby('category')['duration'].max()
longest_duration
# Out:
# category
# baleen whales            48.0
# other marine mammals     24.0
# other seabirds            6.2
# penguins                 32.2
# sea lions                16.0
# seals                   120.0
# toothed whales          222.0
# turtles                  68.5
# walruses                 49.0
# Name: duration, dtype: float64
